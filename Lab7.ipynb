# %% [markdown]
# #  Demo 7: Plotting using Matplotlib & Seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Q1. Load the IPL dataset and display first 10 records.

# %%
data = pd.read_csv('data_CC.csv')
df = pd.DataFrame(data)
data.head(10)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
# 5   6    2008      Jaipur  2008-04-21        Kings XI Punjab
# 6   7    2008   Hyderabad  2008-04-22        Deccan Chargers
# 7   8    2008     Chennai  2008-04-23    Chennai Super Kings
# 8   9    2008   Hyderabad  2008-04-24        Deccan Chargers
# 9  10    2008  Chandigarh  2008-04-25        Kings XI Punjab
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# ...

# %% [markdown]
# Q2. Find the total number of:
# - Matches
# - Teams
# - Seasons

# %%
print("Total Matches conducted are: ", np.shape(data)[0])
print("Total number of teams are: ", len(set(df['team1'])|set(df['team2'])))
print("Total number of seasons are: ", len(df['season'].unique()))
# Out:
# Total Matches conducted are:  577
# Total number of teams are:  13
# Total number of seasons are:  9

# %% [markdown]
# Q3. Plot the number of matches played per season using Matplotlib.

# %%
df['season'].value_counts().sort_index().plot(kind='bar')
plt.xlabel("Season")
plt.ylabel("Number of Matches")
plt.title("Matches per Season")
plt.show()

# %% [markdown]
# Q4. Use Seaborn to visualize:
# > Top 5 teams with most wins

# %%
top_teams = df['winner'].value_counts().head(5)

sns.barplot(x=top_teams.values, y=top_teams.index)

plt.xlabel("Number of Wins")
plt.ylabel("Team")
plt.title("Top 5 Teams with Most Wins")

plt.show()

# %% [markdown]
# Q5. Create a bar plot showing top 10 run scorers.

# %%
print("Lack of data")
# Out:
# Lack of data

# %% [markdown]
# Q6. Plot a pie chart representing match wins by venue.

# %%
vc = df['venue'].value_counts().head(10)
plt.pie(vc.values, labels=vc.index,  autopct='%1.1f%%')
plt.title("Simple Pie Chart")
plt.show()

# %% [markdown]
# Q7. Compare home vs away wins using an appropriate plot.

# %%
df['home_win'] = df['winner'] == df['team1']
df['away_win'] = df['winner'] == df['team2']

home_wins = df['home_win'].sum()
away_wins = df['away_win'].sum()

sns.barplot(x=["Home_Win", "Away_Win"], y=[home_wins, away_wins])

plt.title("Home vs Away Wins")
plt.show()

# %% [markdown]
# Q8. Create a visualization that tells a clear IPL performance story (your choice).

# %% [markdown]
# Q9. Add annotations and titles to improve readability. (Continuation)

# %%
df['toss_win_match_win'] = df['toss_winner'] == df['winner']
result = df.groupby('toss_decision')['toss_win_match_win'].mean()
result = result * 100

plt.figure()
plt.bar(result.index, result.values)
plt.xlabel("Toss Decision")
plt.ylabel("Win % (Toss Winner)")
plt.title("IPL Insight: Does Toss Decision Affect Match Outcome?")

plt.show()
