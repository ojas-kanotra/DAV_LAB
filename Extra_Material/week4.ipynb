# %%
import pandas as pd

data = [10, 20, 30, 40, 50]

my_series = pd.Series(data)
print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd

a = [10, 20, 50]

my_series = pd.Series(a, index = ["monday", "tuesday", "wednesday"])
print(my_series)
# Out:
# monday       10
# tuesday      20
# wednesday    50
# dtype: int64

# %%
import pandas as pd
import numpy as np
attendance = pd.series(
    [132, 94, 112,84, 254, 322, 472],
    index=[
        "Monday",
        "Tuyesday",
        "Wednesday",
        "Thursday",
        "Friday",
        "Saturday",
        "Sunday",
    ],
)
print (attendance)

print("individual temperature")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11968\2041776074.py in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 attendance = pd.series(
#       4     [132, 94, 112,84, 254, 322, 472],
#       5     index=[
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
import pandas as pd
data=pd.read_csv("samplema.csv")
data
# Out:
#   roll no     65  23   34
# 0    name  manas  de  abc
# 1   marks     54  66   sd

# %%
import pandas as pd
data = ('name':['Tom', 'Jack', 'Steve', 'Ricky'])
# Out:
#   File "C:\Users\DAVLAB\AppData\Local\Temp\ipykernel_11968\404920319.py", line 2
#     data = ('name':['Tom', 'Jack', 'Steve', 'Ricky'])
#                   ^
# SyntaxError: invalid syntax
