# %%
print("Happy new year")
# Out:
# Happy new year

# %%
a=28
b=3.14
c="2025"
d=True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
_x=float(input("Enter the first number:"))
_y=float(input("Enter the second number:"))
print("sum=",_x+_y)
# Out:
# Enter the first number:4
# Enter the second number:5
# sum= 9.0

# %%
var_stra="This is my first python class"
var_strb="""string that print
multiple lines
"""
print(var_stra)
print(var_strb)
var_strb.count("\n")
# Out:
# This is my first python class
# string that print
# multiple lines
# 2

# %%
#if else statement
x=int(input("Enter a number:"))
print(type(a))
if x%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a jnumber:2
# <class 'int'>
# Even

# %%
#for loop
name="Riya"
for i in name:
    print(i)
# Out:
# R
# i
# y
# a

# %%
val_list=[1,2,3,4.8,"Riya"]
for i in val_list:
    print(i)
    print(type(i))
# Out:
# 1
# <class 'int'>
# 2
# <class 'int'>
# 3
# <class 'int'>
# 4.8
# <class 'float'>
# Riya
# <class 'str'>

# %%
for i in range
# Out:
#   File "C:\Users\DAVLAB\AppData\Local\Temp\ipykernel_17996\2890242097.py", line 1
#     for i in range
#                   ^
# SyntaxError: invalid syntax

# %%
for i in range(1,6)
    print(i)
# Out:
#   File "C:\Users\DAVLAB\AppData\Local\Temp\ipykernel_17996\65455055.py", line 1
#     for i in range(1,6)
#                        ^
# SyntaxError: invalid syntax

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#python funcions
#function definition
#parameter and return value
#unction reusability
def great(name):
    return "Hello " + name
great("Riya")
# Out:
# 'Hello Riya'

# %%
def add_statement()
