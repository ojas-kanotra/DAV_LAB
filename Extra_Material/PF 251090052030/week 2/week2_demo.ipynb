# %% [markdown]
# # Riya Agrawal
# ##date-15/01/26
# ##registration no.-251090052030
# ##Pf-(60)
# ##list,tuple,set,dictionary,string operations

# %%
#
a_list=[10,24,56,87,99]
print(a_list)
# Out:
# [10, 24, 56, 87, 99]

# %%
b_list=[34,78,22,96,34]
print("list=",b_list)
print("length=",len(b_list))
print("Maximum no=",max(b_list))
print("Minimum no=",min(b_list))
print("total=",sum(b_list))
print("Average=",sum(b_list)/len(b_list))
print("no. of times 34 occur:",b_list.count(34))
# Out:
# list= [34, 78, 22, 96, 34]
# length= 5
# Maximum no= 96
# Minimum no= 22
# total= 264
# Average= 52.8
# no. of times 34 occur: 2

# %%
l=[1,3,4,5]
print("old list=",l)
l.append(6)
l[1]=2
print("new list=",l)
l.append("Riya")
print("new list=",l)
# Out:
# old list= [1, 3, 4, 5]
# new list= [1, 2, 4, 5, 6]
# new list= [1, 2, 4, 5, 6, 'Riya']

# %%
#iterate the list
for i in l:
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6
# Riya

# %%
fruit=["apple","kiwi","strawberry"]
print(fruit)
# Out:
# ['apple', 'kiwi', 'strawberry']

# %%
print(fruit[0])
# Out:
# apple

# %%
fruit[0]="blueberry"

# %%
print
# Out:
# <function print>

# %%
print(fruit)
# Out:
# ['blueberry', 'kiwi', 'strawberry']

# %% [markdown]
# # list methods(functions)
# ## 1)append 2)insert 3)remove 4)sort 5)reverse

# %%
fruit.append("Guava")
print(fruit)
# Out:
# ['blueberry', 'kiwi', 'strawberry', 'Guava']

# %%
l.insert(2,"dragon fruit")
print(fruit)
# Out:
# ['blueberry', 'kiwi', 'strawberry', 'Guava']

# %%
l.remove("Guava")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18456\2272967861.py in <module>
# ----> 1 l.remove("Guava")
#
# ValueError: list.remove(x): x not in list

# %%
l.remove(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18456\511895517.py in <module>
# ----> 1 l.remove(3)
#
# ValueError: list.remove(x): x not in list

# %%
l.insert(5,"banana")
print(fruit)
# Out:
# ['blueberry', 'kiwi', 'strawberry', 'Guava']

# %%
fruit.insert(5."dragon fruit")
print(fruit)
# Out:
#   File "C:\Users\DAVLAB\AppData\Local\Temp\ipykernel_18456\542765949.py", line 1
#     fruit.insert(5."dragon fruit")
#                    ^
# SyntaxError: invalid syntax

# %%
fruit.insert(5,"dragon fruit")
print(fruit)
# Out:
# ['blueberry', 'kiwi', 'strawberry', 'Guava', 'dragon fruit']

# %%
fruit.remove("Guava")
fruit.insert(1,"Guava")
print(fruit)
# Out:
# ['blueberry', 'Guava', 'kiwi', 'strawberry', 'dragon fruit']

# %%
fruit.sort()
print(fruit)
# Out:
# ['Guava', 'blueberry', 'dragon fruit', 'kiwi', 'strawberry']

# %%
fruit.sort(key=len)
print(fruit)
# Out:
# ['kiwi', 'Guava', 'blueberry', 'strawberry', 'dragon fruit']

# %%
#slicing
print(fruit[:3])
print(fruit[0:4])
print(fruit[2:])
print(fruit[3:4])
print(fruit[-1:])
print(fruit[:-1])
# Out:
# ['kiwi', 'Guava', 'blueberry']
# ['kiwi', 'Guava', 'blueberry', 'strawberry']
# ['blueberry', 'strawberry', 'dragon fruit']
# ['strawberry']
# ['dragon fruit']
# ['kiwi', 'Guava', 'blueberry', 'strawberry']

# %%
print(fruit[6:2])
# Out:
# []

# %%
print(fruit[::-1])
# Out:
# ['dragon fruit', 'strawberry', 'blueberry', 'Guava', 'kiwi']

# %%
print(fruit[5:6])
# Out:
# []

# %%
l=["Riya","Tanu"]
print(l)
# Out:
# ['Riya', 'Tanu']

# %%
print(l)
# Out:
# ['Riya', 'Tanu']

# %%
print("Apple" in fruit)
print("apple" not in fruit)
# Out:
# False
# True

# %%
fruit2=["apple","banana"]
fruit
# Out:
# ['kiwi', 'Guava', 'blueberry', 'strawberry', 'dragon fruit']

# %%
fruit+fruit2
# Out:
# ['kiwi', 'Guava', 'blueberry', 'strawberry', 'dragon fruit', 'apple', 'banana']

# %%
fruit
# Out:
# ['kiwi', 'Guava', 'blueberry', 'strawberry', 'dragon fruit']

# %%
fruit.extend(fruit2)

# %%
fruit
# Out:
# ['kiwi', 'Guava', 'blueberry', 'strawberry', 'dragon fruit', 'apple', 'banana']

# %%
fruit.remove("apple")
fruit.remove("banana")
fruit
# Out:
# ['kiwi', 'Guava', 'blueberry', 'strawberry', 'dragon fruit']

# %% [markdown]
# # tuples

# %%
t=[10,20,30]
print(t)
print(tuple(t))
t
# Out:
# [10, 20, 30]
# (10, 20, 30)
# [10, 20, 30]

# %%
t=tuple(t)

# %%
t
# Out:
# (10, 20, 30)

# %%
try:
    t[0]=11
except:
    print("Error!")
# Out:
# Error!

# %%
t[0]=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11172\1178742575.py in <module>
# ----> 1 t[0]=10
#
# TypeError: 'tuple' object does not support item assignment

# %%
try:
    t[0]=10
except TypeError:
    print("Error!")
# Out:
# Error!

# %%
tuple(fruit)
fruit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11172\1806467054.py in <module>
# ----> 1 tuple(fruit)
#       2 fruit
#
# NameError: name 'fruit' is not defined

# %%
fruit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11172\3670734841.py in <module>
# ----> 1 fruit
#
# NameError: name 'fruit' is not defined

# %%
fruit=("Strawberry","Guava","kiwi","Guava")
fruit
print(fruit[0])
# Out:
# Strawberry

# %%
fruit
# Out:
# ('Strawberry', 'Guava', 'kiwi', 'Guava')

# %%
print(fruit.count("Kiwi"))
# Out:
# 0

# %%
fruit
# Out:
# ('Strawberry', 'Guava', 'kiwi', 'Guava')

# %%
print(fruit.count("kiwi"))
# Out:
# 1

# %%
fruit1=list(fruit)

# %%
fruit1
# Out:
# ['Strawberry', 'Guava', 'kiwi', 'Guava']

# %%
fruit
# Out:
# ('Strawberry', 'Guava', 'kiwi', 'Guava')

# %%
detail={"name":"Riya","class":"PF","rollno":62,"registration no":251090052030}
print(detail)
# Out:
# {'name': 'Riya', 'class': 'PF', 'rollno': 62, 'registration no': 251090052030}

# %%
print(detail["name"])
# Out:
# Riya

# %%
person={"name":"Riya","age":18,"city":"Bhilai"}
print(person["name"])
print(person.get("age"))
# Out:
# Riya
# 18

# %%
for i,j in person.items():
    print(i,":",j)
# Out:
# name : Riya
# age : 18
# city : Bhilai

# %%
for i in person.values():
    print(i)
# Out:
# Riya
# 18
# Bhilai

# %%
for i in person.keys():
    print(i,":",person[i])
# Out:
# name : Riya
# age : 18
# city : Bhilai

# %% [markdown]
# # sets

# %%
a={1,2,3}
b={3,4,5}
print("union:",a|b)
print("intersection:",a&b)
print("difference:",a-b)
# Out:
# union: {1, 2, 3, 4, 5}
# intersection: {3}
# difference: {1, 2}

# %% [markdown]
# # string operation

# %%
string1="Python programming"
print(string1.lower())
print(string1.strip())
print(string1.replace("Python","Java"))
# Out:
# python programming
# Python programming
# Java programming

# %%
string1
# Out:
# 'Python programming'

# %%
try:
    num=int(input("enter any number:"))
    print("square:",num*num)
except ValueError:
    print("Error!")
# Out:
# enter any number:Riya
# Error!
