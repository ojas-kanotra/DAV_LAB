# %% [markdown]
# # week2 programs DAV
# -topic: Python built-in Data structures, Functions, modules,
# packages
#
# -Name:Riya Agrawal
#
# -Class:PF,Rollno:46
#
# -regno:251090052030
#
# -date:15/01/2026

# %%
"""1. Write a Python code block that inputs numbers into a list. Print 
the largest, smallest, the sum, and the average of the numbers. 
Count occurrences of a specific number in the list."""
l=[]
length=int(input("Enter the length of list:"))
for i in range(0,length):
    num=int(input("Enter a element:"))
    l.append(num)
print("list:",l)
print("largest element:",max(l))
print("Smallest element:",min(l))
print("Total of the elements:",sum(l))
print("Average:",sum(l)/len(l))
print("no. of times 3 occurs:",l.count(3))
# Out:
# Enter the length of list:5
# Enter a element:1
# Enter a element:2
# Enter a element:3
# Enter a element:4
# Enter a element:5
# list: [1, 2, 3, 4, 5]
# largest element: 5
# Smallest element: 1
# Total of the elements: 15
# Average: 3.0
# no. of times 3 occurs: 1

# %%
"""2. Write a Python code block to create a tuple with five elements. 
Try to change one of the elements and handle the error that 
occurs. Print a message that explains why the error occurred. """
t=()
for i in range(4):
    num=int(input("Enter a element:"))
    t+=(num,)
print("tuple:",t)
try:
    num=int(input("Enter the element to change into"))
    t[0]=num
except TypeError:
    print("Error! tuple is immutable data type, element cannot be changed")
# Out:
# Enter a element:1
# Enter a element:2
# Enter a element:3
# Enter a element:4
# tuple: (1, 2, 3, 4)
# Enter the element to change into5
# Error! tuple is immutable data type, element cannot be changed

# %%
"""3. Write a Python code block to create a dictionary of cricket World 
Cup winners. Let the key be the year; the value is the country that 
won the World Cup that year. Print the name of the best- 
performing country. Display the unique list of countries that 
have won the World Cup. """
d={2007:"India",2008:"SL",2009:"WI",2010:"India",2011:"WI",2012:"India"}
c={}
l=list(d.values())
for i in l:
    c[i]=l.count(i)
l1=list(c.values())
maximum=max(l1)
print("The best performing country is:")
for i,j in c.items():
    if j==maximum:
        print(i)
# Out:
# The best performing country is:
# India

# %%
"""4. Write a Python code block that inputs a sentence from the user. 
Count the frequency of each word in the sentence and store the 
result in a dictionary. Prints the dictionary with words as keys 
and their frequencies as values. """
str=input("Enter a sentence:")
l=str.split()
c={}
for i in l:
    c[i]=l.count(i)
for i,j in c.items():
    print(i,":",j)
# Out:
# Enter a sentence:riya is nice riya
# riya : 2
# is : 1
# nice : 1

# %%
"""Write a Python code block to input numbers into two sets. 
Perform union, intersection, and difference operations on the sets 
and print the results. """
length=int(input("Enter length of the sets:"))
s1=[]
s2=[]
for i in range(length):
    num1=int(input("Enter elements of 1st set:"))
    s1.append(num1)
for i in range(length):
    num2=int(input("Enter elements of 2nd set:"))
    s2.append(num2)
a=set(s1)
b=set(s2)
print("union:",a|b)
print("intersection:",a&b)
print("difference:",a-b)
# Out:
# Enter length of the sets:5
# Enter elements of 1st set:1
# Enter elements of 1st set:2
# Enter elements of 1st set:3
# Enter elements of 1st set:4
# Enter elements of 1st set:5
# Enter elements of 2nd set:6
# Enter elements of 2nd set:7
# Enter elements of 2nd set:8
# Enter elements of 2nd set:9
# Enter elements of 2nd set:5
# union: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# intersection: {5}
# difference: {1, 2, 3, 4}
